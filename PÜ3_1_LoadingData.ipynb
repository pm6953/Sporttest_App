# %% [markdown]
# <table style="width: 100%">
#     <tr style="background: #ffffff">
#         <td style="width: 100%">
#             <div style="text-align:right; width: 100%; text-align:right"><font style="font-size:38px"><b>Übung 3.1: Loading Data</b></font></div>
#             <div style="padding-top:0px; width: 100%; text-align:right"><font size="4"><b>Programmierübung 2</b></font></div>
#         </td>
#     </tr>
# </table>
#
#
# # Loading, displaying and saving data
# ## Aim of this unit
# Learn how to work with typical data formats in the field of medical, health and sports technology. Typical data formats are e.g. .csv and .txt files. In order to work with and process the data in the following exercises, the following skills must first be learned:
# 1. loading data + different data formats
#      - Numpy arrays
#      - Pandas dataframes
#      - Lists
# 2. Working with pandas
#      -  Structure of dataframes
#      -  Storing and Loading CSV-Files
#      -  Advanced pandas
#      -  Group by
#      -  Operations on columns
#      -  Creating new columns
#      -  Simple analysis
# 3. Graphing data
#      - Matplotlib
# 4. Tasks:
#       1. Pandas
#       2. Matplotlib

# %% [markdown]
# <table style="width: 100%">
#     <tr style="background: #ffffff">
#         <td style="width: 100%">
#             <div style="text-align:right; width: 100%; text-align:right"><font style="font-size:38px"><b>1. Loading Data</b></font></div>
#             <div style="padding-top:0px; width: 100%; text-align:right"><font size="4"><b>Programmierübung 2</b></font></div>
#         </td>
#     </tr>
# </table>
#
#
#
# # Loading data + Different data formats
#
# Importing the used libraries
# By "import numpy as np" we can call e.g. numpy functions via _numpy.functionsName_.

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ## Task 1.1
# __Load one .csv and one .txt file each from the "ECG_Data" folder and save the file in one variable each of type Numpy Array, List and Pandas Dataframe.__

# %%
# define path using a string value
directory =  'EKG_Data/'
file_name = "01_Ruhe.txt"
file_name_csv = "01_Ruhe.csv"


## Open the file using the path and define a certain split character
# The files first column are Values in millivolt, second column is time in milliseconds
## Write it into a ... 
# List 
list_01 = open(directory + file_name,"r").read().split("\n")

# %%
list_01[0].split("\t")
# Out:
# ['309', '13666']

# %% [markdown]
# ✍️ **Task**
#
# Print the first five elements of the `list_01`
# - What could the `"\t"` stand for - remember `Huber, Julian`?
# - what could You do to separate the time and voltage?

# %%
list_01[0:5] # Show the first 6 lines of the list
# Out:
# ['309\t13666', '307\t13668', '306\t13670', '304\t13672', '303\t13674']

# %%
#@title ❓ Click `Show code` in the code cell to show the solution. { display-mode: "form" }

print(list_01[0:5])
list_01[0].split("\t")
# Out:
# ['309\t13666', '307\t13668', '306\t13670', '304\t13672', '303\t13674']
# ['309', '13666']

# %%
# Looping the list to split the data in two separate lists
time = []
value = []

for line in list_01:
    _line = line.split("\t")
    value.append(int(_line[0]))
    time.append(int(_line[1]))
    
print("list_01 is of type:" +  str(type(list_01)))
print("time is of type:" +  str(type(time)))
print("value is of type:" +  str(type(value)))
# Out:
# list_01 is of type:<class 'list'>
# time is of type:<class 'list'>
# value is of type:<class 'list'>

# %%
time
# Out:
# [13666,
#  13668,
#  13670,
#  13672,
#  13674,
#  13676,
#  13678,
#  13680,
#  13682,
#  13684,
#  13686,
#  13688,
#  13690,
#  13692,
#  13694,
#  13696,
#  13698,
#  13700,
#  13702,
#  13704,
#  13706,
#  13708,
#  13710,
#  13712,
#  13714,
#  13716,
#  13718,
#  13720,
#  13722,
#  13724,
#  13726,
#  13728,
#  13730,
#  13732,
#  13734,
#  13736,
#  13739,
#  13741,
#  13743,
#  13745,
#  13747,
#  13749,
#  13751,
#  13753,
#  13755,
#  13757,
#  13759,
#  13761,
#  13763,
#  13765,
#  13767,
#  13769,
#  13771,
#  13773,
#  13775,
#  13777,
#  13779,
#  13782,
#  13784,
#  13786,
#  13788,
#  13790,
#  13792,
#  13794,
#  13796,
#  13798,
#  13800,
#  13802,
#  13804,
#  13806,
#  13808,
#  13810,
#  13812,
#  13814,
#  13816,
#  13818,
#  13820,
#  13822,
#  13824,
#  13826,
#  13828,
#  13830,
#  13832,
#  13834,
#  13836,
#  13838,
#  13840,
#  13842,
#  13844,
#  13846,
#  13848,
#  13850,
#  13852,
#  13854,
#  13856,
#  13858,
#  13860,
#  13862,
#  13864,
#  13867,
#  13869,
#  13871,
#  13873,
#  13875,
#  13877,
#  13879,
#  13881,
#  13883,
#  13885,
#  13887,
#  13889,
#  13891,
#  13893,
#  13895,
#  13897,
#  13899,
#  13901,
#  13903,
#  13905,
#  13907,
#  13910,
#  13912,
#  13914,
#  13916,
#  13918,
#  13920,
#  13922,
#  13924,
#  13926,
#  13928,
#  13930,
#  13932,
#  13934,
#  13936,
#  13938,
#  13940,
#  13942,
#  13944,
#  13946,
#  13948,
#  13950,
#  13952,
#  13954,
#  13956,
#  13958,
#  13960,
#  13962,
#  13964,
#  13966,
#  13968,
#  13970,
#  13972,
#  13974,
#  13976,
#  13978,
#  13980,
#  13982,
#  13984,
#  13986,
#  13988,
#  13990,
#  13992,
#  13995,
#  13997,
#  13999,
#  14001,
#  14003,
#  14005,
#  14007,
#  14009,
#  14011,
#  14013,
#  14015,
#  14017,
#  14019,
#  14021,
#  14023,
#  14025,
#  14027,
#  14029,
#  14031,
#  14033,
#  14035,
#  14038,
#  14040,
#  14042,
#  14044,
#  14046,
#  14048,
#  14050,
#  14052,
#  14054,
#  14056,
#  14058,
#  14060,
#  14062,
#  14064,
#  14066,
#  14068,
#  14070,
#  14072,
#  14074,
#  14076,
#  14078,
#  14080,
#  14082,
#  14084,
#  14086,
#  14088,
#  14090,
#  14092,
#  14094,
#  14096,
#  14098,
#  14100,
#  14102,
#  14104,
#  14106,
#  14108,
#  14110,
#  14112,
#  14114,
#  14116,
#  14118,
#  14120,
#  14123,
#  14125,
#  14127,
#  14129,
#  14131,
#  14133,
#  14135,
#  14137,
#  14139,
#  14141,
#  14143,
#  14145,
#  14147,
#  14149,
#  14151,
#  14153,
#  14155,
#  14157,
#  14159,
#  14161,
#  14163,
#  14166,
#  14168,
#  14170,
#  14172,
#  14174,
#  14176,
#  14178,
#  14180,
#  14182,
#  14184,
#  14186,
#  14188,
#  14190,
#  14192,
#  14194,
#  14196,
#  14198,
#  14200,
#  14202,
#  14204,
#  14206,
#  14208,
#  14210,
#  14212,
#  14214,
#  14216,
#  14218,
#  14220,
#  14222,
#  14224,
#  14226,
#  14228,
#  14230,
#  14232,
#  14234,
#  14236,
#  14238,
#  14240,
#  14242,
#  14244,
#  14246,
#  14248,
#  14251,
#  14253,
#  14255,
#  14257,
#  14259,
#  14261,
#  14263,
#  14265,
#  14267,
#  14269,
#  14271,
#  14273,
#  14275,
#  14277,
#  14279,
#  14281,
#  14283,
#  14285,
#  14287,
#  14289,
#  14291,
#  14294,
#  14296,
#  14298,
#  14300,
#  14302,
#  14304,
#  14306,
#  14308,
#  14310,
#  14312,
#  14314,
#  14316,
#  14318,
#  14320,
#  14322,
#  14324,
#  14326,
#  14328,
#  14330,
#  14332,
#  14334,
#  14336,
#  14338,
#  14340,
#  14342,
#  14344,
#  14346,
#  14348,
#  14350,
#  14352,
#  14354,
#  14356,
#  14358,
#  14360,
#  14362,
#  14364,
#  14366,
#  14368,
#  14370,
#  14372,
#  14374,
#  14376,
#  14379,
#  14381,
#  14383,
#  14385,
#  14387,
#  14389,
#  14391,
#  14393,
#  14395,
#  14397,
#  14399,
#  14401,
#  14403,
#  14405,
#  14407,
#  14409,
#  14411,
#  14413,
#  14415,
#  14417,
#  14419,
#  14422,
#  14424,
#  14426,
#  14428,
#  14430,
#  14432,
#  14434,
#  14436,
#  14438,
#  14440,
#  14442,
#  14444,
#  14446,
#  14448,
#  14450,
#  14452,
#  14454,
#  14456,
#  14458,
#  14460,
#  14462,
#  14464,
#  14466,
#  14468,
#  14470,
#  14472,
#  14474,
#  14476,
#  14478,
#  14480,
#  14482,
#  14484,
#  14486,
#  14488,
#  14490,
#  14492,
#  14494,
#  14496,
#  14498,
#  14500,
#  14502,
#  14504,
#  14507,
#  14509,
#  14511,
#  14513,
#  14515,
#  14517,
#  14519,
#  14521,
#  14523,
#  14525,
#  14527,
#  14529,
#  14531,
#  14533,
#  14535,
#  14537,
#  14539,
#  14541,
#  14543,
#  14545,
#  14547,
#  14550,
#  14552,
#  14554,
#  14556,
#  14558,
#  14560,
#  14562,
#  14564,
#  14566,
#  14568,
#  14570,
#  14572,
#  14574,
#  14576,
#  14578,
#  14580,
#  14582,
#  14584,
#  14586,
#  14588,
#  14590,
#  14592,
#  14594,
#  14596,
#  14598,
#  14600,
#  14602,
#  14604,
#  14606,
#  14608,
#  14610,
#  14612,
#  14614,
#  14616,
#  14618,
#  14620,
#  14622,
#  14624,
#  14626,
#  14628,
#  14630,
#  14632,
#  14635,
#  14637,
#  14639,
#  14641,
#  14643,
#  14645,
#  14647,
#  14649,
#  14651,
#  14653,
#  14655,
#  14657,
#  14659,
#  14661,
#  14663,
#  14665,
#  14667,
#  14669,
#  14671,
#  14673,
#  14675,
#  14678,
#  14680,
#  14682,
#  14684,
#  14686,
#  14688,
#  14690,
#  14692,
#  14694,
#  14696,
#  14698,
#  14700,
#  14702,
#  14704,
#  14706,
#  14708,
#  14710,
#  14712,
#  14714,
#  14716,
#  14718,
#  14720,
#  14722,
#  14724,
#  14726,
#  14728,
#  14730,
#  14732,
#  14734,
#  14736,
#  14738,
#  14740,
#  14742,
#  14744,
#  14746,
#  14748,
#  14750,
#  14752,
#  14754,
#  14756,
#  14758,
#  14760,
#  14763,
#  14765,
#  14767,
#  14769,
#  14771,
#  14773,
#  14775,
#  14777,
#  14779,
#  14781,
#  14783,
#  14785,
#  14787,
#  14789,
#  14791,
#  14793,
#  14795,
#  14797,
#  14799,
#  14801,
#  14803,
#  14806,
#  14808,
#  14810,
#  14812,
#  14814,
#  14816,
#  14818,
#  14820,
#  14822,
#  14824,
#  14826,
#  14828,
#  14830,
#  14832,
#  14834,
#  14836,
#  14838,
#  14840,
#  14842,
#  14844,
#  14846,
#  14848,
#  14850,
#  14852,
#  14854,
#  14856,
#  14858,
#  14860,
#  14862,
#  14864,
#  14866,
#  14868,
#  14870,
#  14872,
#  14874,
#  14876,
#  14878,
#  14880,
#  14882,
#  14884,
#  14886,
#  14888,
#  14891,
#  14893,
#  14895,
#  14897,
#  14899,
#  14901,
#  14903,
#  14905,
#  14907,
#  14909,
#  14911,
#  14913,
#  14915,
#  14917,
#  14919,
#  14921,
#  14923,
#  14925,
#  14927,
#  14929,
#  14931,
#  14934,
#  14936,
#  14938,
#  14940,
#  14942,
#  14944,
#  14946,
#  14948,
#  14950,
#  14952,
#  14954,
#  14956,
#  14958,
#  14960,
#  14962,
#  14964,
#  14966,
#  14968,
#  14970,
#  14972,
#  14974,
#  14976,
#  14978,
#  14980,
#  14982,
#  14984,
#  14986,
#  14988,
#  14990,
#  14992,
#  14994,
#  14996,
#  14998,
#  15000,
#  15002,
#  15004,
#  15006,
#  15008,
#  15010,
#  15012,
#  15014,
#  15016,
#  15019,
#  15021,
#  15023,
#  15025,
#  15027,
#  15029,
#  15031,
#  15033,
#  15035,
#  15037,
#  15039,
#  15041,
#  15043,
#  15045,
#  15047,
#  15049,
#  15051,
#  15053,
#  15055,
#  15057,
#  15059,
#  15062,
#  15064,
#  15066,
#  15068,
#  15070,
#  15072,
#  15074,
#  15076,
#  15078,
#  15080,
#  15082,
#  15084,
#  15086,
#  15088,
#  15090,
#  15092,
#  15094,
#  15096,
#  15098,
#  15100,
#  15102,
#  15104,
#  15106,
#  15108,
#  15110,
#  15112,
#  15114,
#  15116,
#  15118,
#  15120,
#  15122,
#  15124,
#  15126,
#  15128,
#  15130,
#  15132,
#  15134,
#  15136,
#  15138,
#  15140,
#  15142,
#  15144,
#  15147,
#  15149,
#  15151,
#  15153,
#  15155,
#  15157,
#  15159,
#  15161,
#  15163,
#  15165,
#  15167,
#  15169,
#  15171,
#  15173,
#  15175,
#  15177,
#  15179,
#  15181,
#  15183,
#  15185,
#  15187,
#  15190,
#  15192,
#  15194,
#  15196,
#  15198,
#  15200,
#  15202,
#  15204,
#  15206,
#  15208,
#  15210,
#  15212,
#  15214,
#  15216,
#  15218,
#  15220,
#  15222,
#  15224,
#  15226,
#  15228,
#  15230,
#  15232,
#  15234,
#  15236,
#  15238,
#  15240,
#  15242,
#  15244,
#  15246,
#  15248,
#  15250,
#  15252,
#  15254,
#  15256,
#  15258,
#  15260,
#  15262,
#  15264,
#  15266,
#  15268,
#  15270,
#  15272,
#  15275,
#  15277,
#  15279,
#  15281,
#  15283,
#  15285,
#  15287,
#  15289,
#  15291,
#  15293,
#  15295,
#  15297,
#  15299,
#  15301,
#  15303,
#  15305,
#  15307,
#  15309,
#  15311,
#  15313,
#  15315,
#  15318,
#  15320,
#  15322,
#  15324,
#  15326,
#  15328,
#  15330,
#  15332,
#  15334,
#  15336,
#  15338,
#  15340,
#  15342,
#  15344,
#  15346,
#  15348,
#  15350,
#  15352,
#  15354,
#  15356,
#  15358,
#  15360,
#  15362,
#  15364,
#  15366,
#  15368,
#  15370,
#  15372,
#  15374,
#  15376,
#  15378,
#  15380,
#  15382,
#  15384,
#  15386,
#  15388,
#  15390,
#  15392,
#  15394,
#  15396,
#  15398,
#  15400,
#  15403,
#  15405,
#  15407,
#  15409,
#  15411,
#  15413,
#  15415,
#  15417,
#  15419,
#  15421,
#  15423,
#  15425,
#  15427,
#  15429,
#  15431,
#  15433,
#  15435,
#  15437,
#  15439,
#  15441,
#  15443,
#  15446,
#  15448,
#  15450,
#  15452,
#  15454,
#  15456,
#  15458,
#  15460,
#  15462,
#  15464,
#  15466,
#  15468,
#  15470,
#  15472,
#  15474,
#  15476,
#  15478,
#  15480,
#  15482,
#  15484,
#  15486,
#  15488,
#  15490,
#  15492,
#  15494,
#  15496,
#  15498,
#  15500,
#  15502,
#  15504,
#  15506,
#  15508,
#  15510,
#  15512,
#  15514,
#  15516,
#  15518,
#  15520,
#  15522,
#  15524,
#  15526,
#  15528,
#  15531,
#  15533,
#  15535,
#  15537,
#  15539,
#  15541,
#  15543,
#  15545,
#  15547,
#  15549,
#  15551,
#  15553,
#  15555,
#  15557,
#  15559,
#  15561,
#  15563,
#  15565,
#  15567,
#  15569,
#  15571,
#  15574,
#  15576,
#  15578,
#  15580,
#  15582,
#  15584,
#  15586,
#  15588,
#  15590,
#  15592,
#  15594,
#  15596,
#  15598,
#  15600,
#  15602,
#  15604,
#  15606,
#  15608,
#  15610,
#  15612,
#  15614,
#  15616,
#  15618,
#  15620,
#  15622,
#  15624,
#  15626,
#  15628,
#  15630,
#  15632,
#  15634,
#  15636,
#  15638,
#  15640,
#  15642,
#  15644,
#  15646,
#  15648,
#  15650,
#  15652,
#  15654,
#  15656,
#  15659,
#  15661,
#  15663,
#  15665,
#  15667,
#  15669,
#  15671,
#  15673,
#  15675,
#  15677,
#  15679,
#  15681,
#  15683,
#  15685,
#  15687,
#  15689,
#  15691,
#  15693,
#  15695,
#  ...]

# %%
# Numpy Array
array_01_test = np.array(list_01)

print("array_01_test is of type:" +  str(type(array_01_test)))
# The array is still containing the "\t" separator, instead we could use the two lists "value","time" and stack them into one array... input has to be a tupel 
array_01 = np.column_stack((time, value)) 
print("after stacking the two list in one array it is of type:" + str(type(array_01)))
# Out:
# array_01_test is of type:<class 'numpy.ndarray'>
# after stacking the two list in one array it is of type:<class 'numpy.ndarray'>

# %%
array_01_test
# Out:
# array(['309\t13666', '307\t13668', '306\t13670', ..., '298\t633011',
#        '299\t633013', '300\t633015'], shape=(304837,), dtype='<U10')

# %% [markdown]
# ✍️ **Task**
#
# Try to load the list_01 directly into a data frame: `df_01 = pd.DataFrame(list_01)`

# %%
df_01 = pd.DataFrame(list_01)#
print("df_01 is of type:" +  str(type(df_01)))
# Out:
# df_01 is of type:<class 'pandas.core.frame.DataFrame'>

# %%
#@title ❓ Click `Show code` in the code cell to show the solution. { display-mode: "form" }
df_01 = pd.DataFrame(list_01)

# %%
# Pandas dataframe
print("df_01 is of type:" +  str(type(df_01)))

print("the first 5 rows of the dataframe look like this: ")
print(df_01.head())
# Out:
# df_01 is of type:<class 'pandas.core.frame.DataFrame'>
# the first 5 rows of the dataframe look like this:
#             0
# 0  309\t13666
# 1  307\t13668
# 2  306\t13670
# 3  304\t13672
# 4  303\t13674

# %%
df_01
# Out:
#                   0
# 0        309\t13666
# 1        307\t13668
# 2        306\t13670
# 3        304\t13672
# 4        303\t13674
# ...             ...
# 304832  296\t633007
# 304833  297\t633009
# 304834  298\t633011
# 304835  299\t633013
# 304836  300\t633015
#
# [304837 rows x 1 columns]

# %% [markdown]
# ## Task 1.2
#
# Notice, that the dataframe still contains the tabulator "\t" in it. There is a easier and more elegant way than using "open" and converting it into a list first.
#
# ✍️ **Task**
# Look up the pandas function __"pd.read_csv"__ and use it, to load the txt. and .csv file into a dataframe. Please also add a header with the column names :`"Amplitude in [mV]" ,"Time in [ms]"`

# %%
df_ruhe_01 = pd.read_csv(r"EKG_Data\01_Ruhe.csv", sep=';')
df_ruhe_01
# Out:
#         309   13666
# 0       307   13668
# 1       306   13670
# 2       304   13672
# 3       303   13674
# 4       301   13676
# ...     ...     ...
# 304831  296  633007
# 304832  297  633009
# 304833  298  633011
# 304834  299  633013
# 304835  300  633015
#
# [304836 rows x 2 columns]

# %%
#@title ❓ Click `Show code` in the code cell to show the solution. { display-mode: "form" }

df_ruhe_01 = pd.read_csv(directory + file_name, sep='\t')
print(df_ruhe_01.head())

# for csv file
column_names = ["Amplitude in [mV]" ,"Time in [ms]"]
df_ruhe_01_csv = pd.read_csv(directory + file_name_csv, sep=';',header= None , names= column_names)
df_ruhe_01_csv.head()
# Out:
#    309  13666
# 0  307  13668
# 1  306  13670
# 2  304  13672
# 3  303  13674
# 4  301  13676
#    Amplitude in [mV]  Time in [ms]
# 0                309         13666
# 1                307         13668
# 2                306         13670
# 3                304         13672
# 4                303         13674

# %% [markdown]
# ## Task 1.3
#
# The pandas built-in loading function is very powerful, since it can be modified by multiple input parameters in the function.
#
# ✍️ **Task**
# Use the function with all its capabilities, given the following csv file __TrackManData__ in the Data folder. The goal is to extract the ```Attack Angle, Ball Speed, Impact Offset, Impact Height and the Tags```. Please use following parameters ```header, usecols, skiprows``` to delete the first (0) row and use the second (1) row as header. Also the row, containing the units for the data, should be deleted.

# %%
path= r"Data/TrackManData.csv"
column_names = ["Date","Attack Angle","Ball Speed","Impact Offset", "Impact height", "Tags"]
df=pd.read_csv(path, sep=',', header=1, usecols=column_names, skiprows=[2])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 3
#       1 path= r"Data/TrackManData.csv"
#       2 column_names = ["Date","Attack Angle","Ball Speed","Impact Offset", "Impact height", "Tags"]
# ----> 3 df=pd.read_csv(path, sep=',', header=1, usecols=column_names, skiprows=[2])
#       4 df
#
# File c:\Users\gabse\git\aufgabe_3-5\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\gabse\git\aufgabe_3-5\.venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\gabse\git\aufgabe_3-5\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\gabse\git\aufgabe_3-5\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File c:\Users\gabse\git\aufgabe_3-5\.venv\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:140, in CParserWrapper.__init__(self, src, **kwds)
#     136 assert self.orig_names is not None
#     137 if self.usecols_dtype == "string" and not set(usecols).issubset(
#     138     self.orig_names
#     139 ):
# --> 140     self._validate_usecols_names(usecols, self.orig_names)
#     142 # error: Cannot determine type of 'names'
#     143 if len(self.names) > len(usecols):  # type: ignore[has-type]
#     144     # error: Cannot determine type of 'names'
#
# File c:\Users\gabse\git\aufgabe_3-5\.venv\Lib\site-packages\pandas\io\parsers\base_parser.py:979, in ParserBase._validate_usecols_names(self, usecols, names)
#     977 missing = [c for c in usecols if c not in names]
#     978 if len(missing) > 0:
# --> 979     raise ValueError(
#     980         f"Usecols do not match columns, columns expected but not found: "
#     981         f"{missing}"
#     982     )
#     984 return usecols
#
# ValueError: Usecols do not match columns, columns expected but not found: ['Impact height']

# %%
#@title ❓ Click `Show code` in the code cell to show the solution. { display-mode: "form" }

path = 'Data/TrackManData.csv'
column_names = ["Date" ,"Ball Speed","Attack Angle", "Impact Offset", "Impact Height", "Tags"]
df = pd.read_csv(path, sep=',', header=1, usecols= column_names, skiprows=[2])
df
# Out:
#                     Date  Attack Angle  Ball Speed  Impact Offset  \
# 0    07/03/2023 11:13:07          -3.2   99.411686      -7.491821
# 1    07/03/2023 11:13:27          -3.8   88.652246      -2.598809
# 2    07/03/2023 11:13:45          -5.0   95.383635     -12.938655
# 3    07/03/2023 11:14:05          -7.0   77.429537     -24.977253
# 4    07/03/2023 11:14:14          -6.2   85.826995     -14.545176
# ..                   ...           ...         ...            ...
# 630  07/03/2023 19:11:52          -4.6  100.315408       2.536391
# 631  07/03/2023 19:11:59          -6.0  102.087509      -3.898698
# 632  07/03/2023 19:12:07          -3.8   98.375313      -0.033804
# 633  07/03/2023 19:12:14          -5.0  100.832588      -0.281904
# 634  07/03/2023 19:12:22          -4.2  106.901620       2.414463
#
#      Impact Height Tags
# 0         5.623008  S01
# 1        13.469382  S01
# 2         4.380596  S01
# 3        -0.892102  S01
# 4        -3.636012  S01
# ..             ...  ...
# 630       7.523918  S27
# 631      -0.810778  S27
# 632      10.371121  S27
# 633       1.514000  S27
# 634       4.642359  S27
#
# [635 rows x 6 columns]

# %% [markdown]
# # 🏁 Recap Loading Data
#
# - If you have finished the tasks and have no questions, start with the exercice provided on SAKAI.
# - If you have finished the tasks but would like to discuss the solutions together again, please tell your teacher!
#
# <table style="width: 100%">
#     <tr style="background: #ff9900">
#         <td style="width: 100%">
#             <div style="text-align:center; width: 100%; text-align:center"><font style="font-size:38px"><b>Good Job!</b></font></div>
#             <div style="padding-top:0px; width: 100%; text-align:right"><font size="4"><b>SoSe 2023</b></font></div>
#         </td>
#     </tr>
# </table>
